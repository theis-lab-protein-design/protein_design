# %%
import importlib
import warnings
warnings.filterwarnings('ignore')
import os
import sys
sys.path.append('pipeline')
from pipeline import run_diffusion, run_protein_mpnn
from Bio import PDB
import nglview as nv
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datetime import datetime
output_folder = f"pipeline_runs/pipeline_run_c8_{datetime.now().strftime('%d-%m-%Y-%H:%M:%S')}"
rf_diffusion_output_folder = output_folder + "/rf_diffusion"
os.makedirs(rf_diffusion_output_folder, exist_ok=True)
rf_diffusion_output_prefix = rf_diffusion_output_folder + "/structure"
rf_diffusion_output_path = run_diffusion(rf_diffusion_output_prefix, 50, "c4")
# Out:
# /root/miniforge3/envs/protein_design_env/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'symmetry': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# [2024-07-17 16:51:02,137][__main__][INFO] - Found GPU with device_name NVIDIA L40S. Will run RFdiffusion on NVIDIA L40S
# Reading models from /root/protein_design/modules/RFdiffusion/rfdiffusion/inference/../../models
# [2024-07-17 16:51:02,138][rfdiffusion.inference.model_runners][INFO] - Reading checkpoint from /root/protein_design/modules/RFdiffusion/rfdiffusion/inference/../../models/Base_ckpt.pt
# This is inf_conf.ckpt_path
# /root/protein_design/modules/RFdiffusion/rfdiffusion/inference/../../models/Base_ckpt.pt
# Assembling -model, -diffuser and -preprocess configs from checkpoint
# USING MODEL CONFIG: self._conf[model][n_extra_block] = 4
# USING MODEL CONFIG: self._conf[model][n_main_block] = 32
# USING MODEL CONFIG: self._conf[model][n_ref_block] = 4
# USING MODEL CONFIG: self._conf[model][d_msa] = 256
# USING MODEL CONFIG: self._conf[model][d_msa_full] = 64
# USING MODEL CONFIG: self._conf[model][d_pair] = 128
# USING MODEL CONFIG: self._conf[model][d_templ] = 64
# USING MODEL CONFIG: self._conf[model][n_head_msa] = 8
# USING MODEL CONFIG: self._conf[model][n_head_pair] = 4
# USING MODEL CONFIG: self._conf[model][n_head_templ] = 4
# USING MODEL CONFIG: self._conf[model][d_hidden] = 32
# USING MODEL CONFIG: self._conf[model][d_hidden_templ] = 32
# USING MODEL CONFIG: self._conf[model][p_drop] = 0.15
# USING MODEL CONFIG: self._conf[model][SE3_param_full] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 8, 'l0_out_features': 8, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 32}
# USING MODEL CONFIG: self._conf[model][SE3_param_topk] = {'num_layers': 1, 'num_channels': 32, 'num_degrees': 2, 'n_heads': 4, 'div': 4, 'l0_in_features': 64, 'l0_out_features': 64, 'l1_in_features': 3, 'l1_out_features': 2, 'num_edge_features': 64}
# USING MODEL CONFIG: self._conf[model][freeze_track_motif] = False
# USING MODEL CONFIG: self._conf[model][use_motif_timestep] = True
# USING MODEL CONFIG: self._conf[diffuser][T] = 50
# USING MODEL CONFIG: self._conf[diffuser][b_0] = 0.01
# USING MODEL CONFIG: self._conf[diffuser][b_T] = 0.07
# USING MODEL CONFIG: self._conf[diffuser][schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][so3_type] = igso3
# USING MODEL CONFIG: self._conf[diffuser][crd_scale] = 0.25
# USING MODEL CONFIG: self._conf[diffuser][so3_schedule_type] = linear
# USING MODEL CONFIG: self._conf[diffuser][min_b] = 1.5
# USING MODEL CONFIG: self._conf[diffuser][max_b] = 2.5
# USING MODEL CONFIG: self._conf[diffuser][min_sigma] = 0.02
# USING MODEL CONFIG: self._conf[diffuser][max_sigma] = 1.5
# USING MODEL CONFIG: self._conf[preprocess][sidechain_input] = False
# USING MODEL CONFIG: self._conf[preprocess][motif_sidechain_input] = True
# USING MODEL CONFIG: self._conf[preprocess][d_t1d] = 22
# USING MODEL CONFIG: self._conf[preprocess][d_t2d] = 44
# USING MODEL CONFIG: self._conf[preprocess][prob_self_cond] = 0.5
# USING MODEL CONFIG: self._conf[preprocess][str_self_cond] = True
# USING MODEL CONFIG: self._conf[preprocess][predict_previous] = False
# WARNING: You are changing diffuser.T from the value this model was trained with. Are you sure you know what you are doing?
# [2024-07-17 16:51:10,429][rfdiffusion.inference.model_runners][INFO] - Loading checkpoint.
# [2024-07-17 16:51:14,533][rfdiffusion.diffusion][INFO] - Calculating IGSO3.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 os.makedirs(rf_diffusion_output_folder, exist_ok=True)
#       5 rf_diffusion_output_prefix = rf_diffusion_output_folder + "/structure"
# ----> 6 rf_diffusion_output_path = run_diffusion(rf_diffusion_output_prefix, 50, "c4")
#
# File ~/protein_design/pipeline/pipeline.py:85, in run_diffusion(output_prefix, total_steps, symmetry)
#      74     raise ValueError("output_prefix must be provided")
#      75 process = subprocess.Popen([
#      76     "python", "./modules/RFdiffusion/scripts/run_inference.py",
#      77     "--config-name", "symmetry",
#    (...)
#      82     f"diffuser.T={total_steps}"
#      83 ])
# ---> 85 process.communicate()
#      87 output_path =  output_prefix + "_0.pdb"
#      88 print("RFDiffusion output can be found at", output_path)
#
# File ~/miniforge3/envs/protein_design_env/lib/python3.9/subprocess.py:1126, in Popen.communicate(self, input, timeout)
#    1124         stderr = self.stderr.read()
#    1125         self.stderr.close()
# -> 1126     self.wait()
#    1127 else:
#    1128     if timeout is not None:
#
# File ~/miniforge3/envs/protein_design_env/lib/python3.9/subprocess.py:1189, in Popen.wait(self, timeout)
#    1187     endtime = _time() + timeout
#    1188 try:
# -> 1189     return self._wait(timeout=timeout)
#    1190 except KeyboardInterrupt:
#    1191     # https://bugs.python.org/issue25942
#    1192     # The first keyboard interrupt waits briefly for the child to
#    1193     # exit under the common assumption that it also received the ^C
#    1194     # generated SIGINT and will exit rapidly.
#    1195     if timeout is not None:
#
# File ~/miniforge3/envs/protein_design_env/lib/python3.9/subprocess.py:1933, in Popen._wait(self, timeout)
#    1931 if self.returncode is not None:
#    1932     break  # Another thread waited.
# -> 1933 (pid, sts) = self._try_wait(0)
#    1934 # Check the pid and loop as waitpid has been known to
#    1935 # return 0 even without WNOHANG in odd situations.
#    1936 # http://bugs.python.org/issue14396.
#    1937 if pid == self.pid:
#
# File ~/miniforge3/envs/protein_design_env/lib/python3.9/subprocess.py:1891, in Popen._try_wait(self, wait_flags)
#    1889 """All callers to this function MUST hold self._waitpid_lock."""
#    1890 try:
# -> 1891     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1892 except ChildProcessError:
#    1893     # This happens if SIGCLD is set to be ignored or waiting
#    1894     # for child processes has otherwise been disabled for our
#    1895     # process.  This child is dead, we can't get the status.
#    1896     pid = self.pid
#
# KeyboardInterrupt:
# Successful diffuser __init__
# [2024-07-17 16:51:34,554][rfdiffusion.inference.symmetry][INFO] - Initializing cyclic symmetry order 4.
# [2024-07-17 16:51:34,560][__main__][INFO] - Making design pipeline_runs/pipeline_run_c8_17-07-2024-16:51:00/rf_diffusion/structure_0
# [2024-07-17 16:51:34,565][rfdiffusion.inference.model_runners][INFO] - Using contig: ['360-360']
# With this beta schedule (linear schedule, beta_0 = 0.04, beta_T = 0.28), alpha_bar_T = 0.00013696048699785024
# [2024-07-17 16:51:34,757][rfdiffusion.inference.model_runners][INFO] - Sequence init: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# /root/miniforge3/envs/protein_design_env/lib/python3.9/site-packages/e3nn/o3/_spherical_harmonics.py:82: UserWarning: FALLBACK path has been taken inside: compileCudaFusionGroup. This is an indication that codegen Failed for some reason.
# To debug try disable codegen fallback path via setting the env variable `export PYTORCH_NVFUSER_DISABLE=fallback`
# To report the issue, try enable logging via setting the envvariable ` export PYTORCH_JIT_LOG_LEVEL=manager.cpp`
#  (Triggered internally at  /home/conda/feedstock_root/build_artifacts/pytorch-recipe_1664405705473/work/torch/csrc/jit/codegen/cuda/manager.cpp:237.)
#   sh = _spherical_harmonics(self._lmax, x[..., 0], x[..., 1], x[..., 2])
# /root/miniforge3/envs/protein_design_env/lib/python3.9/site-packages/e3nn/o3/_spherical_harmonics.py:82: UserWarning: FALLBACK path has been taken inside: runCudaFusionGroup. This is an indication that codegen Failed for some reason.
# To debug try disable codegen fallback path via setting the env variable `export PYTORCH_NVFUSER_DISABLE=fallback`
#  (Triggered internally at  /home/conda/feedstock_root/build_artifacts/pytorch-recipe_1664405705473/work/torch/csrc/jit/codegen/cuda/manager.cpp:329.)
#   sh = _spherical_harmonics(self._lmax, x[..., 0], x[..., 1], x[..., 2])
# [2024-07-17 16:51:38,163][rfdiffusion.inference.model_runners][INFO] - Timestep 50, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:39,821][rfdiffusion.inference.model_runners][INFO] - Timestep 49, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:41,441][rfdiffusion.inference.model_runners][INFO] - Timestep 48, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:43,024][rfdiffusion.inference.model_runners][INFO] - Timestep 47, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:44,642][rfdiffusion.inference.model_runners][INFO] - Timestep 46, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:46,279][rfdiffusion.inference.model_runners][INFO] - Timestep 45, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:47,980][rfdiffusion.inference.model_runners][INFO] - Timestep 44, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:49,679][rfdiffusion.inference.model_runners][INFO] - Timestep 43, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:51,391][rfdiffusion.inference.model_runners][INFO] - Timestep 42, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:53,038][rfdiffusion.inference.model_runners][INFO] - Timestep 41, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:54,670][rfdiffusion.inference.model_runners][INFO] - Timestep 40, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:56,329][rfdiffusion.inference.model_runners][INFO] - Timestep 39, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:57,952][rfdiffusion.inference.model_runners][INFO] - Timestep 38, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:51:59,567][rfdiffusion.inference.model_runners][INFO] - Timestep 37, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:01,255][rfdiffusion.inference.model_runners][INFO] - Timestep 36, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:02,860][rfdiffusion.inference.model_runners][INFO] - Timestep 35, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:04,546][rfdiffusion.inference.model_runners][INFO] - Timestep 34, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:06,141][rfdiffusion.inference.model_runners][INFO] - Timestep 33, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:07,743][rfdiffusion.inference.model_runners][INFO] - Timestep 32, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:09,341][rfdiffusion.inference.model_runners][INFO] - Timestep 31, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:10,963][rfdiffusion.inference.model_runners][INFO] - Timestep 30, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:12,649][rfdiffusion.inference.model_runners][INFO] - Timestep 29, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:14,261][rfdiffusion.inference.model_runners][INFO] - Timestep 28, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:15,931][rfdiffusion.inference.model_runners][INFO] - Timestep 27, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:17,565][rfdiffusion.inference.model_runners][INFO] - Timestep 26, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:19,240][rfdiffusion.inference.model_runners][INFO] - Timestep 25, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:20,835][rfdiffusion.inference.model_runners][INFO] - Timestep 24, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:22,535][rfdiffusion.inference.model_runners][INFO] - Timestep 23, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:24,125][rfdiffusion.inference.model_runners][INFO] - Timestep 22, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:25,738][rfdiffusion.inference.model_runners][INFO] - Timestep 21, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:27,356][rfdiffusion.inference.model_runners][INFO] - Timestep 20, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:29,068][rfdiffusion.inference.model_runners][INFO] - Timestep 19, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:30,743][rfdiffusion.inference.model_runners][INFO] - Timestep 18, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:32,345][rfdiffusion.inference.model_runners][INFO] - Timestep 17, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:33,975][rfdiffusion.inference.model_runners][INFO] - Timestep 16, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:35,605][rfdiffusion.inference.model_runners][INFO] - Timestep 15, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:37,279][rfdiffusion.inference.model_runners][INFO] - Timestep 14, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:38,973][rfdiffusion.inference.model_runners][INFO] - Timestep 13, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:40,717][rfdiffusion.inference.model_runners][INFO] - Timestep 12, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:42,356][rfdiffusion.inference.model_runners][INFO] - Timestep 11, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:43,996][rfdiffusion.inference.model_runners][INFO] - Timestep 10, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:45,658][rfdiffusion.inference.model_runners][INFO] - Timestep 9, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:47,364][rfdiffusion.inference.model_runners][INFO] - Timestep 8, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:49,082][rfdiffusion.inference.model_runners][INFO] - Timestep 7, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:50,785][rfdiffusion.inference.model_runners][INFO] - Timestep 6, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:52,455][rfdiffusion.inference.model_runners][INFO] - Timestep 5, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:54,130][rfdiffusion.inference.model_runners][INFO] - Timestep 4, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:55,763][rfdiffusion.inference.model_runners][INFO] - Timestep 3, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:52:57,441][rfdiffusion.inference.model_runners][INFO] - Timestep 2, input to next step: ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [2024-07-17 16:53:02,079][__main__][INFO] - Finished design in 1.46 minutes

# %%
nv.show_biopython(PDB.PDBParser(QUIET=True).get_structure('protein', rf_diffusion_output_path))
# Out:
# NGLWidget()

# %%
protein_mpnn_output_folder = output_folder + "/protein_mpnn/";
if not os.path.exists(protein_mpnn_output_folder):
    os.makedirs(protein_mpnn_output_folder)
else:
    for filename in os.listdir(protein_mpnn_output_folder):
        file_path = os.path.join(protein_mpnn_output_folder, filename)
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)

run_protein_mpnn(input_folder=rf_diffusion_output_folder, output_folder=protein_mpnn_output_folder, num_seq_per_target=10)
# Out:
# Running ProteinMPNN
# ProteinMPNN finished, output can be found at pipeline_runs/pipeline_run_c8_17-07-2024-14:25:43/protein_mpnn/
